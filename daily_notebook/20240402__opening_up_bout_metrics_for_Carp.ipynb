# %%
import numpy as np
import pandas as pd
import scipy
from scipy import stats
import suncalc

import dask.dataframe as dd
from pathlib import Path
import glob
import re

import datetime as dt

import matplotlib.pyplot as plt
from matplotlib import colors
import soundfile as sf
import matplotlib.patches as patches

# %%
import sys

sys.path.append("../src")
sys.path.append("../src/bout")
sys.path.append("../src/tests")

# %%
import bout.clustering as clstr
import bout.assembly as bt
import bout.plot as bt_plt
import test_activity_metric_functions as test_actvt
import activity.subsampling as ss
import activity.activity_assembly as actvt
import pipeline
from core import SITE_NAMES, FREQUENCY_COLOR_MAPPINGS

from cli import get_file_paths
import pipeline

# %%
POINT_CMAP = {0:'w',1:'r',2:'b',3:'g',4:'orange',5:'c',6:'pink',7:'k'}
POINT_CMAP
# Out:
# {0: 'w', 1: 'r', 2: 'b', 3: 'g', 4: 'orange', 5: 'c', 6: 'pink', 7: 'k'}

# %%
def plot_dets_over_audio_seg(audio_features, spec_features, plot_dets, data_params):
    """
    Function to plot the spectrogram of a provided audio segment with overlayed detections
    """

    audio_seg = audio_features['audio_seg']
    fs = audio_features['sample_rate']
    start = audio_features['start']
    duration = audio_features['duration']

    plt.figure(figsize=(15, 5))
    plt.title(f"BatDetect2 detections on {audio_features['file_path'].name}", fontsize=22)
    plt.rcParams.update({'font.size': 24})
    plt.specgram(audio_seg, NFFT=spec_features['NFFT'], cmap=spec_features['cmap'], vmin=spec_features['vmin'])

    yellow_patch = patches.Patch(facecolor='yellow', edgecolor='k', label='Detections')

    legend_patches = [yellow_patch]
    ax = plt.gca()
    for i, row in plot_dets.iterrows():
        rect = patches.Rectangle(((row['start_time'] - start)*(fs/2), row['low_freq']/(fs/2)), 
                        (row['end_time'] - row['start_time'])*(fs/2), (row['high_freq'] - row['low_freq'])/(fs/2), 
                        linewidth=2, edgecolor='yellow', facecolor='none', alpha=0.8)
        
        ax.add_patch(rect)
        
    plt.yticks(ticks=np.linspace(0, 1, 6), labels=np.linspace(0, fs/2000, 6).astype('int'))
    plt.xticks(ticks=np.linspace(0, duration*(fs/2), 11), labels=np.round(np.linspace(start, start+duration, 11, dtype='float'), 2), rotation=30)
    plt.ylabel("Frequency (kHz)")
    plt.xlabel("Time (s)")
    plt.gcf().autofmt_xdate()
    plt.legend(handles=legend_patches, fontsize=20, ncol=int(len(legend_patches)**0.5), loc='upper right')

    plt.tight_layout()
    plt.show()

# %%
site_key = 'Carp'
freq_key = 'LF'

files_from_loc = sorted(list(Path(f'../data/audiomoth_recordings/').glob(pattern=f'*/{site_key}/*.WAV')))
file_path = Path(files_from_loc[0])
filename = file_path.name
audio_file = sf.SoundFile(file_path)
fs = audio_file.samplerate
start = 0
duration = 780
audio_file.seek(int(fs*start))
audio_seg = audio_file.read(int(fs*duration))
vmin = 20*np.log10(np.max(audio_seg)) - 60 # hide anything below -rm_dB dB

pipeline_params = dict()
pipeline_params['assemble_location_summary'] = True
pipeline_params["read_csv"] = False
pipeline_params['use_threshold_to_group'] = False
pipeline_params['use_kmeans_to_group'] = True

audio_features = dict()
audio_features['file_path'] = file_path
audio_features['audio_seg'] = audio_seg
audio_features['sample_rate'] = fs
audio_features['start'] = start
audio_features['duration'] = duration

spec_features = dict()
spec_features['vmin'] = vmin
spec_features['NFFT'] = 1024
spec_features['cmap'] = 'jet'
csv_path = Path(f'../data/raw/{site_key}/bd2__{site_key}_{filename.split(".")[0]}.csv')

data_params = dict()
data_params['site_tag'] = site_key
data_params['type_tag'] = freq_key
data_params['recording_start'] = '00:00'
data_params['recording_end'] = '16:00'
data_params['cur_dc_tag'] = '6of6'
data_params['cycle_length'] = int(data_params['cur_dc_tag'].split('of')[-1])
data_params['time_on'] = int(data_params['cur_dc_tag'].split('of')[0])
data_params['time_on_in_secs'] = 60*data_params['time_on']
file_paths = get_file_paths(data_params)

location_df = pd.read_csv(f'{file_paths["SITE_folder"]}/{file_paths["bd2_TYPE_SITE_YEAR"]}.csv', index_col=0)
bout_params = bt.get_bout_params_from_location(location_df, data_params)

# %%
dc_applied_df = ss.simulate_dutycycle_on_detections(location_df.copy(), data_params)

# %%
tagged_dets = bt.classify_bouts_in_bd2_predictions_for_freqgroups(dc_applied_df, bout_params)
bout_metrics_LF = bt.construct_bout_metrics_from_location_df_for_freqgroups(tagged_dets)

# %%
file_paths
# Out:
# {'raw_SITE_folder': '/Users/adityakrishna/duty-cycle-investigation/src/../data/raw/Carp',
#  'SITE_folder': '/Users/adityakrishna/duty-cycle-investigation/src/../data/2022_bd2_summary/Carp',
#  'SITE_classes_folder': '/Users/adityakrishna/duty-cycle-investigation/src/../data/classifications/Carp',
#  'SITE_classes_file': '/Users/adityakrishna/duty-cycle-investigation/src/../data/classifications/Carp/2022_Carp_call_classes.csv',
#  'bd2_TYPE_SITE_YEAR': 'bd2__LFCarp_2022',
#  'duty_cycled_folder': '/Users/adityakrishna/duty-cycle-investigation/src/../data/2022_bd2_summary/Carp/duty_cycled',
#  'dc_dets_TYPE_SITE_summary': 'dc_dets_LFCarp_summary',
#  'dc_bouts_TYPE_SITE_summary': 'dc_bouts_LFCarp_summary',
#  'dc_inds_TYPE_SITE_summary': 'dc_inds_LFCarp_summary',
#  'dc_callrate_TYPE_SITE_summary': 'dc_callrate_LFCarp_summary',
#  'cont_callrate_TYPE_SITE_summary': 'cont_callrate_LFCarp_summary',
#  'dc_btp_TYPE_SITE_summary': 'dc_btp_LFCarp_summary',
#  'cont_btp_TYPE_SITE_summary': 'cont_btp_LFCarp_summary',
#  'dc_actind_TYPE_SITE_summary': 'dc_actind_LFCarp_summary',
#  'cont_actind_TYPE_SITE_summary': 'cont_actind_LFCarp_summary',
#  'figures_SITE_folder': '/Users/adityakrishna/duty-cycle-investigation/src/../figures/Carp',
#  'activity_det_comparisons_figname': 'activity_det_comparisons_per_dc_LFCarp',
#  'dc_det_comparisons_figname': 'dc_det_comparisons_per_night_LFCarp',
#  'activity_bout_comparisons_figname': 'activity_bout_comparisons_per_dc_LFCarp',
#  'dc_bout_comparisons_figname': 'dc_bout_comparisons_per_night_LFCarp',
#  'activity_ind_comparisons_figname': 'activity_ind_comparisons_per_dc_LFCarp',
#  'dc_ind_comparisons_figname': 'dc_ind_comparisons_per_night_LFCarp',
#  'dc_metric_comparisons_figname': 'metric_comparisons_per_night_LFCarp',
#  'presence_comparisons_figname': 'presence_comparisons_per_dc_LFCarp'}

# %%
bout_durations_raw_LF = bout_metrics_LF['bout_duration_in_secs'].values
plt.figure(figsize=(12,4))
plt.rcParams.update({'font.size':14})
plt.hist(bout_durations_raw_LF, bins=np.arange(0, bout_durations_raw_LF.max(), 1), edgecolor='k')
plt.grid(which='both')
plt.yscale('log')
plt.xscale('log')
plt.xlim(1,1e4)
plt.show()

# %%
plot_dets = dc_applied_df.loc[(dc_applied_df['call_start_time']>=dt.datetime(2022,7,27,8,0,0))&(dc_applied_df['call_end_time']<=dt.datetime(2022,7,27,8,30,0))]
plot_dets = plot_dets.loc[np.logical_and(plot_dets['start_time'] >= start, plot_dets['end_time'] <= (start+duration))]

# %%
plot_dets_over_audio_seg(audio_features, spec_features, plot_dets, data_params)

# %%
plot_bouts = bout_metrics.loc[(bout_metrics['start_time_of_bout']>=dt.datetime(2022,7,27,8,0,0))&(bout_metrics['end_time_of_bout']<=dt.datetime(2022,7,27,8,30,0))]
plot_bouts = plot_bouts.loc[np.logical_and(plot_bouts['start_time'] >= start, plot_bouts['end_time'] <= (start+duration))]

# %%
bt_plt.plot_bouts_over_audio_seg(audio_features, spec_features, bout_params, data_params, plot_bouts)

# %%
site_key = 'Carp'
freq_key = 'HF'

files_from_loc = sorted(list(Path(f'../data/audiomoth_recordings/').glob(pattern=f'*/{site_key}/*.WAV')))
file_path = Path(files_from_loc[0])
filename = file_path.name
audio_file = sf.SoundFile(file_path)
fs = audio_file.samplerate
start = 0
duration = 780
audio_file.seek(int(fs*start))
audio_seg = audio_file.read(int(fs*duration))
vmin = 20*np.log10(np.max(audio_seg)) - 60 # hide anything below -rm_dB dB

pipeline_params = dict()
pipeline_params['assemble_location_summary'] = True
pipeline_params["read_csv"] = False
pipeline_params['use_threshold_to_group'] = False
pipeline_params['use_kmeans_to_group'] = True

audio_features = dict()
audio_features['file_path'] = file_path
audio_features['audio_seg'] = audio_seg
audio_features['sample_rate'] = fs
audio_features['start'] = start
audio_features['duration'] = duration

spec_features = dict()
spec_features['vmin'] = vmin
spec_features['NFFT'] = 1024
spec_features['cmap'] = 'jet'
csv_path = Path(f'../data/raw/{site_key}/bd2__{site_key}_{filename.split(".")[0]}.csv')

data_params = dict()
data_params['site_tag'] = site_key
data_params['type_tag'] = freq_key
data_params['recording_start'] = '00:00'
data_params['recording_end'] = '16:00'
data_params['cur_dc_tag'] = '6of6'
data_params['cycle_length'] = int(data_params['cur_dc_tag'].split('of')[-1])
data_params['time_on'] = int(data_params['cur_dc_tag'].split('of')[0])
data_params['time_on_in_secs'] = 60*data_params['time_on']
file_paths = get_file_paths(data_params)

location_df = pd.read_csv(f'{file_paths["SITE_folder"]}/{file_paths["bd2_TYPE_SITE_YEAR"]}.csv', index_col=0)
bout_params = bt.get_bout_params_from_location(location_df, data_params)

# %%
location_df
# Out:
#          index_in_file  peak_frequency  index_in_summary        input_file_dt  \
# 74                  31         44160.0                74  2022-07-13 05:00:00
# 75                  32         42240.0                75  2022-07-13 05:00:00
# 76                  33         42240.0                76  2022-07-13 05:00:00
# 77                  34         42240.0                77  2022-07-13 05:00:00
# 78                  35         42240.0                78  2022-07-13 05:00:00
# ...                ...             ...               ...                  ...
# 1014185             19         48960.0           1016357  2022-10-17 13:30:00
# 1014186             20         48960.0           1016358  2022-10-17 13:30:00
# 1014187             21         46080.0           1016359  2022-10-17 13:30:00
# 1014188             22         48000.0           1016360  2022-10-17 13:30:00
# 1014189             23         50880.0           1016361  2022-10-17 13:30:00
#
#         freq_group                       ref_time  \
# 74              HF  2022-07-13 05:06:41.952500000
# 75              HF  2022-07-13 05:06:42.639500000
# 76              HF  2022-07-13 05:06:42.734500000
# 77              HF  2022-07-13 05:06:42.828500000
# 78              HF  2022-07-13 05:06:42.934500000
# ...            ...                            ...
# 1014185         HF  2022-10-17 13:40:28.967500000
# 1014186         HF  2022-10-17 13:40:29.670500000
# 1014187         HF  2022-10-17 13:40:29.864500000
# 1014188         HF  2022-10-17 13:40:29.951500000
# 1014189         HF  2022-10-17 13:40:30.302500000
#
#                        call_start_time                  call_end_time  \
# 74       2022-07-13 05:06:41.952500000  2022-07-13 05:06:41.959300000
# 75       2022-07-13 05:06:42.639500000  2022-07-13 05:06:42.650500000
# 76       2022-07-13 05:06:42.734500000  2022-07-13 05:06:42.744100000
# 77       2022-07-13 05:06:42.828500000  2022-07-13 05:06:42.836000000
# 78       2022-07-13 05:06:42.934500000  2022-07-13 05:06:42.941700000
# ...                                ...                            ...
# 1014185  2022-10-17 13:40:28.967500000  2022-10-17 13:40:28.972900000
# 1014186  2022-10-17 13:40:29.670500000  2022-10-17 13:40:29.676400000
# 1014187  2022-10-17 13:40:29.864500000  2022-10-17 13:40:29.871300000
# 1014188  2022-10-17 13:40:29.951500000  2022-10-17 13:40:29.960300000
# 1014189  2022-10-17 13:40:30.302500000  2022-10-17 13:40:30.309200000
#
#          start_time  end_time  ...         event                      class  \
# 74         401.9525  401.9593  ...  Echolocation      Pipistrellus nathusii
# 75         402.6395  402.6505  ...  Echolocation      Pipistrellus nathusii
# 76         402.7345  402.7441  ...  Echolocation      Pipistrellus nathusii
# 77         402.8285  402.8360  ...  Echolocation      Pipistrellus nathusii
# 78         402.9345  402.9417  ...  Echolocation      Pipistrellus nathusii
# ...             ...       ...  ...           ...                        ...
# 1014185    628.9675  628.9729  ...  Echolocation  Pipistrellus pipistrellus
# 1014186    629.6705  629.6764  ...  Echolocation  Pipistrellus pipistrellus
# 1014187    629.8645  629.8713  ...  Echolocation  Pipistrellus pipistrellus
# 1014188    629.9515  629.9603  ...  Echolocation  Pipistrellus pipistrellus
# 1014189    630.3025  630.3092  ...  Echolocation  Pipistrellus pipistrellus
#
#         class_prob det_prob  individual  \
# 74           0.438    0.557          -1
# 75           0.533    0.603          -1
# 76           0.550    0.638          -1
# 77           0.548    0.607          -1
# 78           0.611    0.648          -1
# ...            ...      ...         ...
# 1014185      0.536    0.639          -1
# 1014186      0.458    0.618          -1
# 1014187      0.526    0.636          -1
# 1014188      0.375    0.541          -1
# 1014189      0.287    0.503          -1
#
#                                                 input_file  Site name  \
# 74       /mnt/ubna_data_01_mir/recover-20220715/UBNA_00...  Carp Pond
# 75       /mnt/ubna_data_01_mir/recover-20220715/UBNA_00...  Carp Pond
# 76       /mnt/ubna_data_01_mir/recover-20220715/UBNA_00...  Carp Pond
# 77       /mnt/ubna_data_01_mir/recover-20220715/UBNA_00...  Carp Pond
# 78       /mnt/ubna_data_01_mir/recover-20220715/UBNA_00...  Carp Pond
# ...                                                    ...        ...
# 1014185  /mnt/ubna_data_02_mir/recover-20221017/UBNA_01...  Carp Pond
# 1014186  /mnt/ubna_data_02_mir/recover-20221017/UBNA_01...  Carp Pond
# 1014187  /mnt/ubna_data_02_mir/recover-20221017/UBNA_01...  Carp Pond
# 1014188  /mnt/ubna_data_02_mir/recover-20221017/UBNA_01...  Carp Pond
# 1014189  /mnt/ubna_data_02_mir/recover-20221017/UBNA_01...  Carp Pond
#
#            Recover Folder SD Card File Duration
# 74       recover-20220715       8        1795.0
# 75       recover-20220715       8        1795.0
# 76       recover-20220715       8        1795.0
# 77       recover-20220715       8        1795.0
# 78       recover-20220715       8        1795.0
# ...                   ...     ...           ...
# 1014185  recover-20221017      10        1795.0
# 1014186  recover-20221017      10        1795.0
# 1014187  recover-20221017      10        1795.0
# 1014188  recover-20221017      10        1795.0
# 1014189  recover-20221017      10        1795.0
#
# [111537 rows x 22 columns]

# %%
dc_applied_df = ss.simulate_dutycycle_on_detections(location_df.copy(), data_params)

# %%
tagged_dets = bt.classify_bouts_in_bd2_predictions_for_freqgroups(dc_applied_df, bout_params)
bout_metrics_HF = bt.construct_bout_metrics_from_location_df_for_freqgroups(tagged_dets)

# %%
bout_durations_raw_HF = bout_metrics_HF['bout_duration_in_secs'].values
plt.rcParams.update({'font.size':14})
plt.figure(figsize=(12,4))
plt.hist(bout_durations_raw_HF, bins=np.arange(0, bout_durations_raw_HF.max(), 1), edgecolor='k')
plt.grid(which='both')
plt.yscale('log')
plt.xscale('log')
plt.xlim(1,1e4)
plt.show()

# %%
plot_dets = dc_applied_df.loc[(dc_applied_df['call_start_time']>=dt.datetime(2022,7,27,8,0,0))&(dc_applied_df['call_end_time']<=dt.datetime(2022,7,27,8,30,0))]
plot_dets = plot_dets.loc[np.logical_and(plot_dets['start_time'] >= start, plot_dets['end_time'] <= (start+duration))]

# %%
plot_dets_over_audio_seg(audio_features, spec_features, plot_dets, data_params)

# %%
plot_bouts = bout_metrics.loc[(bout_metrics['start_time_of_bout']>=dt.datetime(2022,7,27,8,0,0))&(bout_metrics['end_time_of_bout']<=dt.datetime(2022,7,27,8,30,0))]
plot_bouts = plot_bouts.loc[np.logical_and(plot_bouts['start_time'] >= start, plot_bouts['end_time'] <= (start+duration))]

# %%
bt_plt.plot_bouts_over_audio_seg(audio_features, spec_features, bout_params, data_params, plot_bouts)

# %%
bout_durations_raw_HF = bout_metrics_HF['bout_duration_in_secs'].values
bout_durations_raw_LF = bout_metrics_LF['bout_duration_in_secs'].values
plt.rcParams.update({'font.size':14})
plt.figure(figsize=(12,4))
x_lims = [9, 1.8e3]
x_step = 1
plt.hist(bout_durations_raw_LF, bins=np.arange(x_lims[0],x_lims[-1], x_step), edgecolor='k')
plt.hist(bout_durations_raw_HF, bins=np.arange(x_lims[0],x_lims[-1], x_step), edgecolor='k')
plt.grid(which='both')
plt.yscale('log')
plt.xscale('log')
plt.xlim(x_lims[0],x_lims[-1])
plt.show()

# %%
bout_metrics_LF[bout_metrics_LF['bout_duration_in_secs']>1000]
# Out:
#               start_time_of_bout           end_time_of_bout  \
# 19986 2022-09-01 03:33:51.952500 2022-09-01 03:59:54.881700
#
#        start_time_wrt_ref  end_time_wrt_ref  start_time   end_time  low_freq  \
# 19986            231.9525          354.8817    231.9525  1794.8817   20312.0
#
#        high_freq freq_group cycle_ref_time_start  cycle_ref_time_end  \
# 19986    47507.0         LF  2022-09-01 03:30:00 2022-09-01 03:54:00
#
#        number_of_dets          bout_duration  bout_duration_in_secs
# 19986           12513 0 days 00:26:02.929200              1562.9292

# %%
location_df = pd.read_csv(f'{file_paths["SITE_folder"]}/bd2__LFCarp_2022.csv', index_col=0)
file_LF_dets = location_df[pd.to_datetime(location_df['input_file_dt'])==dt.datetime(2022,9,1,3,30,0)].copy()

# %%
file_LF_dets['input_file'].unique().item()
# Out:
# '/mnt/ubna_data_02/recover-20220901/UBNA_005/20220901_033000.WAV'

# %%
bout_metrics_HF[bout_metrics_HF['bout_duration_in_secs']>60]
# Out:
#              start_time_of_bout           end_time_of_bout  \
# 5650 2022-09-18 04:35:46.301500 2022-09-18 04:36:52.986500
#
#       start_time_wrt_ref  end_time_wrt_ref  start_time  end_time  low_freq  \
# 5650            346.3015           52.9865    346.3015  412.9865   35781.0
#
#       high_freq freq_group cycle_ref_time_start  cycle_ref_time_end  \
# 5650    71238.0         HF  2022-09-18 04:30:00 2022-09-18 04:36:00
#
#       number_of_dets          bout_duration  bout_duration_in_secs
# 5650             492 0 days 00:01:06.685000                 66.685

# %%
location_df = pd.read_csv(f'{file_paths["SITE_folder"]}/bd2__HFCarp_2022.csv', index_col=0)
file_HF_dets = location_df[pd.to_datetime(location_df['input_file_dt'])==dt.datetime(2022,9,18,4,30,0)].copy()

# %%
file_HF_dets['input_file'].unique().item()
# Out:
# '/mnt/ubna_data_02/recover-20220919/UBNA_010/20220918_043000.WAV'
