# %%
import numpy as np
import pandas as pd
import scipy
from scipy import stats
import datetime as dt

import matplotlib.pyplot as plt
from matplotlib import colors
import soundfile as sf
import matplotlib.patches as patches
from pathlib import Path

# %%
import sys

sys.path.append("../src")
sys.path.append("../src/bout")

# %%
from core import SITE_NAMES, FREQ_GROUPS
import clustering as clstr
import bout.assembly as bt
import bout.clustering as clstr
import plot as bt_plt
import activity.subsampling as ss
import activity.activity_assembly as actvt
import pipeline

from cli import get_file_paths

# %%
slater = 0
sibly = 0
for site_key in ['Carp', 'Foliage', 'Telephone', 'Central']:
    for freq_key in ['LF', 'HF']:
        bout_params = dict()
        bout_params['site_key'] = site_key
        bout_params['freq_key'] = freq_key

        fig_details = dict()
        fig_details['site_name'] = SITE_NAMES[site_key]
        fig_details['freq_group'] = freq_key.split('_')[0].upper()
        if freq_key:
            fig_details['freq_group'] = fig_details['freq_group'] + ' '
        fig_details['bin_step'] = 10
        fig_details['time_end'] = 2000
        print(f'Looking at {fig_details["site_name"]}')

        location_df = pd.read_csv(f'../data/2022_detector_summaries/{bout_params["site_key"]}/bd2__{bout_params["freq_key"]}{bout_params["site_key"]}_2022_kmeans.csv', index_col=0, low_memory=False)
        ipis_loc, hist_loc = clstr.get_histogram(location_df, fig_details['bin_step'])
        intervals_ms, survival = clstr.get_log_survival(hist_loc)

        fast_process = clstr.regress_around_fast_intervals(intervals_ms, survival, hist_loc[0])
        fast_process = clstr.calculate_exponential_coefficients(fast_process)

        slow_process = clstr.regress_around_slow_intervals(intervals_ms, survival)
        slow_process = clstr.calculate_exponential_coefficients(slow_process)

        fg_bci, misassigned_points_fg = clstr.get_bci_from_fagenyoung_method(fast_process, slow_process)
        print(f"Fagen&Young method has {round(misassigned_points_fg)} misassigned points")
        bci, misassigned_points = clstr.get_bci_from_slater_method(intervals_ms, survival, fast_process, slow_process)
        print(f"Slater method has {round(misassigned_points)} misassigned points")
        nlin_results, misassigned_points_optim = clstr.get_bci_from_sibly_method(intervals_ms, survival, fast_process, slow_process)
        print(f"Sibly method has {round(misassigned_points_optim)} misassigned points")
        print(f"Optim BCI has less misassignments than BCI? {misassigned_points_optim < misassigned_points}")
        if misassigned_points_optim < misassigned_points:
            diff = int(misassigned_points - misassigned_points_optim)
            sibly+=diff
            print(f"{diff} more points assigned correctly by Sibly")
        else:
            diff = int(misassigned_points_optim - misassigned_points)
            slater+=diff
            print(f"{diff} more points assigned correctly by Slater")

        fig_details['time_end'] = 60000
        fig_details['site_name'] = SITE_NAMES[site_key]
        # bt_plt.plot_nlin_results_over_survival(intervals_ms, survival, fast_process, slow_process, nlin_results['solution'], nlin_results['bci'], bci, fig_details)

        data_params = dict()
        data_params['type_tag'] = freq_key
        data_params['site_tag'] = site_key
        data_params['cur_dc_tag'] = '5of30'
        data_params['bin_size'] = '30'
        data_params['detector_tag'] = 'bd2'
        data_params['use_thresholds'] = False
        data_params['assembly_type'] = 'kmeans'
        fig_details['site_name'] = SITE_NAMES[site_key] + ' ' + f"({data_params['cur_dc_tag']})"

        file_paths = get_file_paths(data_params)

        location_df = ss.prepare_summary_for_plotting_with_duty_cycle_and_bins(file_paths, data_params['cur_dc_tag'], data_params['bin_size'])
        ipis_loc, hist_loc = clstr.get_histogram(location_df, fig_details['bin_step'])
        intervals_ms, survival = clstr.get_log_survival(hist_loc)

        fast_process = clstr.regress_around_fast_intervals(intervals_ms, survival, hist_loc[0])
        fast_process = clstr.calculate_exponential_coefficients(fast_process)

        slow_process = clstr.regress_around_slow_intervals(intervals_ms, survival)
        slow_process = clstr.calculate_exponential_coefficients(slow_process)

        fg_bci, misassigned_points_fg = clstr.get_bci_from_fagenyoung_method(fast_process, slow_process)
        print(f"Fagen&Young method has {round(misassigned_points_fg)} misassigned points")
        bci, misassigned_points = clstr.get_bci_from_slater_method(intervals_ms, survival, fast_process, slow_process)
        print(f"Slater method has {round(misassigned_points)} misassigned points")
        nlin_results, misassigned_points_optim = clstr.get_bci_from_sibly_method(intervals_ms, survival, fast_process, slow_process)
        print(f"Sibly method has {round(misassigned_points_optim)} misassigned points")
        print(f"Optim BCI has less misassignments than BCI? {misassigned_points_optim < misassigned_points}")
        if misassigned_points_optim < misassigned_points:
            diff = int(misassigned_points - misassigned_points_optim)
            sibly+=diff
            print(f"{diff} more points assigned correctly by Sibly")
        else:
            diff = int(misassigned_points_optim - misassigned_points)
            slater+=diff
            print(f"{diff} more points assigned correctly by Slater")
        # bt_plt.plot_nlin_results_over_survival(intervals_ms, survival, fast_process, slow_process, nlin_results['solution'], nlin_results['bci'], bci, fig_details)

        data_params = dict()
        data_params['type_tag'] = freq_key
        data_params['site_tag'] = site_key
        data_params['cur_dc_tag'] = '1of6'
        data_params['bin_size'] = '30'
        data_params['detector_tag'] = 'bd2'
        data_params['use_thresholds'] = False
        data_params['assembly_type'] = 'kmeans'
        fig_details['site_name'] = SITE_NAMES[site_key] + ' ' + f"({data_params['cur_dc_tag']})"

        file_paths = get_file_paths(data_params)

        location_df = ss.prepare_summary_for_plotting_with_duty_cycle_and_bins(file_paths, data_params['cur_dc_tag'], data_params['bin_size'])
        ipis_loc, hist_loc = clstr.get_histogram(location_df, fig_details['bin_step'])
        intervals_ms, survival = clstr.get_log_survival(hist_loc)

        fast_process = clstr.regress_around_fast_intervals(intervals_ms, survival, hist_loc[0])
        fast_process = clstr.calculate_exponential_coefficients(fast_process)

        slow_process = clstr.regress_around_slow_intervals(intervals_ms, survival)
        slow_process = clstr.calculate_exponential_coefficients(slow_process)

        fg_bci, misassigned_points_fg = clstr.get_bci_from_fagenyoung_method(fast_process, slow_process)
        print(f"Fagen&Young method has {round(misassigned_points_fg)} misassigned points")
        bci, misassigned_points = clstr.get_bci_from_slater_method(intervals_ms, survival, fast_process, slow_process)
        print(f"Slater method has {round(misassigned_points)} misassigned points")
        nlin_results, misassigned_points_optim = clstr.get_bci_from_sibly_method(intervals_ms, survival, fast_process, slow_process)
        print(f"Sibly method has {round(misassigned_points_optim)} misassigned points")
        print(f"Optim BCI has less misassignments than BCI? {misassigned_points_optim < misassigned_points}")
        if misassigned_points_optim < misassigned_points:
            diff = int(misassigned_points - misassigned_points_optim)
            sibly+=diff
            print(f"{diff} more points assigned correctly by Sibly")
        else:
            diff = int(misassigned_points_optim - misassigned_points)
            slater+=diff
            print(f"{diff} more points assigned correctly by Slater")

        # bt_plt.plot_nlin_results_over_survival(intervals_ms, survival, fast_process, slow_process, nlin_results['solution'], nlin_results['bci'], bci, fig_details)
# Out:
# Looking at Carp Pond
# Fagen&Young method has 2007839855 misassigned points
# Slater method has 3033010 misassigned points
# Sibly method has 2916334 misassigned points
# Optim BCI has less misassignments than BCI? True
# 116676 more points assigned correctly by Sibly
# Fagen&Young method has 1445640878 misassigned points
# Slater method has 1449602 misassigned points
# Sibly method has 1390431 misassigned points
# Optim BCI has less misassignments than BCI? True
# 59171 more points assigned correctly by Sibly
# Fagen&Young method has 1458229243 misassigned points
# Slater method has 1413260 misassigned points
# Sibly method has 1371979 misassigned points
# Optim BCI has less misassignments than BCI? True
# 41280 more points assigned correctly by Sibly
# Looking at Carp Pond
# Fagen&Young method has 1193583478 misassigned points
# Slater method has 1969127 misassigned points
# Sibly method has 2853760 misassigned points
# Optim BCI has less misassignments than BCI? False
# 884633 more points assigned correctly by Slater
# Fagen&Young method has 1526194780 misassigned points
# Slater method has 1291608 misassigned points
# /Users/adityakrishna/duty-cycle-investigation/daily_notebook/../src/bout/clustering.py:179: RuntimeWarning: overflow encountered in exp
#   return (np.log((f_intervals*f_lambda*np.exp(-1*f_lambda*t))  + (s_intervals*s_lambda*np.exp(-1*s_lambda*t))))
# /Users/adityakrishna/duty-cycle-investigation/daily_notebook/../src/bout/clustering.py:179: RuntimeWarning: overflow encountered in multiply
#   return (np.log((f_intervals*f_lambda*np.exp(-1*f_lambda*t))  + (s_intervals*s_lambda*np.exp(-1*s_lambda*t))))
# /Users/adityakrishna/duty-cycle-investigation/daily_notebook/../src/bout/clustering.py:179: RuntimeWarning: invalid value encountered in log
#   return (np.log((f_intervals*f_lambda*np.exp(-1*f_lambda*t))  + (s_intervals*s_lambda*np.exp(-1*s_lambda*t))))
# Sibly method has 1060118 misassigned points
# Optim BCI has less misassignments than BCI? True
# 231490 more points assigned correctly by Sibly
# Fagen&Young method has 1358936595 misassigned points
# Slater method has 1025930 misassigned points
# Sibly method has 1503857 misassigned points
# Optim BCI has less misassignments than BCI? False
# 477927 more points assigned correctly by Slater
# Looking at Foliage
# Fagen&Young method has 2375248923 misassigned points
# Slater method has 4052925 misassigned points
# Sibly method has 4047632 misassigned points
# Optim BCI has less misassignments than BCI? True
# 5293 more points assigned correctly by Sibly
# Fagen&Young method has 2678189020 misassigned points
# Slater method has 2789605 misassigned points
# Sibly method has 2968881 misassigned points
# Optim BCI has less misassignments than BCI? False
# 179276 more points assigned correctly by Slater
# Fagen&Young method has 2131607316 misassigned points
# Slater method has 2060909 misassigned points
# Sibly method has 2127575 misassigned points
# Optim BCI has less misassignments than BCI? False
# 66665 more points assigned correctly by Slater
# Looking at Foliage
# Fagen&Young method has 1549459205 misassigned points
# Slater method has 3106815 misassigned points
# Sibly method has 2593617 misassigned points
# Optim BCI has less misassignments than BCI? True
# 513197 more points assigned correctly by Sibly
# Fagen&Young method has 2096799406 misassigned points
# Slater method has 2129877 misassigned points
# Sibly method has 1834114 misassigned points
# Optim BCI has less misassignments than BCI? True
# 295762 more points assigned correctly by Sibly
# Fagen&Young method has 2176342320 misassigned points
# Slater method has 2392607 misassigned points
# Sibly method has 2171125 misassigned points
# Optim BCI has less misassignments than BCI? True
# 221481 more points assigned correctly by Sibly
# Looking at Telephone Field
# Fagen&Young method has 1681022428 misassigned points
# Slater method has 1577483 misassigned points
# Sibly method has 1578928 misassigned points
# Optim BCI has less misassignments than BCI? False
# 1445 more points assigned correctly by Slater
# Fagen&Young method has 483296403 misassigned points
# Slater method has 303543 misassigned points
# Sibly method has 314647 misassigned points
# Optim BCI has less misassignments than BCI? False
# 11104 more points assigned correctly by Slater
# Fagen&Young method has 818285907 misassigned points
# Slater method has 343134 misassigned points
# Sibly method has 423601 misassigned points
# Optim BCI has less misassignments than BCI? False
# 80467 more points assigned correctly by Slater
# Looking at Telephone Field
# Fagen&Young method has 827327557 misassigned points
# Slater method has 1811795 misassigned points
# Sibly method has 2523114 misassigned points
# Optim BCI has less misassignments than BCI? False
# 711319 more points assigned correctly by Slater
# Fagen&Young method has 1137644826 misassigned points
# Slater method has 960358 misassigned points
# Sibly method has 1365929 misassigned points
# Optim BCI has less misassignments than BCI? False
# 405571 more points assigned correctly by Slater
# Fagen&Young method has 1121868139 misassigned points
# Slater method has 894946 misassigned points
# Sibly method has 919474 misassigned points
# Optim BCI has less misassignments than BCI? False
# 24527 more points assigned correctly by Slater
# Looking at Central Pond
# Fagen&Young method has 1765550492 misassigned points
# Slater method has 2119061 misassigned points
# Sibly method has 2190000 misassigned points
# Optim BCI has less misassignments than BCI? False
# 70939 more points assigned correctly by Slater
# Fagen&Young method has 1361445726 misassigned points
# Slater method has 1248297 misassigned points
# Sibly method has 1313237 misassigned points
# Optim BCI has less misassignments than BCI? False
# 64940 more points assigned correctly by Slater
# Fagen&Young method has 1430176895 misassigned points
# Slater method has 1485166 misassigned points
# Sibly method has 1624879 misassigned points
# Optim BCI has less misassignments than BCI? False
# 139713 more points assigned correctly by Slater
# Looking at Central Pond
# Fagen&Young method has 1377158517 misassigned points
# Slater method has 2980422 misassigned points
# Sibly method has 2332391 misassigned points
# Optim BCI has less misassignments than BCI? True
# 648030 more points assigned correctly by Sibly
# Fagen&Young method has 1354451413 misassigned points
# Slater method has 1276631 misassigned points
# Sibly method has 1319757 misassigned points
# Optim BCI has less misassignments than BCI? False
# 43125 more points assigned correctly by Slater
# Fagen&Young method has 1405663657 misassigned points
# Slater method has 1270661 misassigned points
# Sibly method has 1035072 misassigned points
# Optim BCI has less misassignments than BCI? True
# 235588 more points assigned correctly by Sibly

# %%
slater
# Out:
# 3161651

# %%
sibly
# Out:
# 2367968

# %%
slater = 0
sibly = 0
for site_key in ['Carp', 'Foliage', 'Telephone', 'Central']:
    for freq_key in ['LF', 'HF']:
        bout_params = dict()
        bout_params['site_key'] = site_key
        bout_params['freq_key'] = freq_key

        fig_details = dict()
        fig_details['site_name'] = SITE_NAMES[site_key]
        fig_details['freq_group'] = freq_key.split('_')[0].upper()
        if freq_key:
            fig_details['freq_group'] = fig_details['freq_group'] + ' '
        fig_details['bin_step'] = 10
        fig_details['time_end'] = 2000
        print(f'Looking at {fig_details["site_name"]}')

        location_df = pd.read_csv(f'../data/2022_detector_summaries/{bout_params["site_key"]}/bd2__{bout_params["freq_key"]}{bout_params["site_key"]}_2022_kmeans.csv', index_col=0, low_memory=False)
        ipis_loc, hist_loc = clstr.get_histogram(location_df, fig_details['bin_step'])
        intervals_ms, survival = clstr.get_log_survival(hist_loc)

        fast_process = clstr.regress_around_fast_intervals(intervals_ms, survival, hist_loc[0])
        fast_process = clstr.calculate_exponential_coefficients(fast_process)

        slow_process = clstr.regress_around_slow_intervals(intervals_ms, survival)
        slow_process = clstr.calculate_exponential_coefficients(slow_process)

        fg_bci, misassigned_points_fg = clstr.get_bci_from_fagenyoung_method(fast_process, slow_process)
        print(f"Fagen&Young method has {round(misassigned_points_fg)} misassigned points")
        bci, misassigned_points = clstr.get_bci_from_slater_method(intervals_ms, survival, fast_process, slow_process)
        print(f"Slater method has {round(misassigned_points)} misassigned points")
        nlin_results, misassigned_points_optim = clstr.get_bci_from_sibly_method(intervals_ms, survival, fast_process, slow_process)
        print(f"Sibly method has {round(misassigned_points_optim)} misassigned points")
        print(f"Optim BCI has less misassignments than BCI? {misassigned_points_optim < misassigned_points}")
        if misassigned_points_optim < misassigned_points:
            diff = int(misassigned_points - misassigned_points_optim)
            sibly+=misassigned_points_optim
            print(f"{diff} more points assigned correctly by Sibly")
        else:
            diff = int(misassigned_points_optim - misassigned_points)
            slater+=misassigned_points
            print(f"{diff} more points assigned correctly by Slater")


        fig_details['time_end'] = 60000
        fig_details['site_name'] = SITE_NAMES[site_key]
        # bt_plt.plot_nlin_results_over_survival(intervals_ms, survival, fast_process, slow_process, nlin_results['solution'], nlin_results['bci'], bci, fig_details)

        data_params = dict()
        data_params['type_tag'] = freq_key
        data_params['site_tag'] = site_key
        data_params['cur_dc_tag'] = '5of30'
        data_params['bin_size'] = '30'
        data_params['detector_tag'] = 'bd2'
        data_params['use_thresholds'] = False
        data_params['assembly_type'] = 'kmeans'
        fig_details['site_name'] = SITE_NAMES[site_key] + ' ' + f"({data_params['cur_dc_tag']})"

        file_paths = get_file_paths(data_params)

        location_df = ss.prepare_summary_for_plotting_with_duty_cycle_and_bins(file_paths, data_params['cur_dc_tag'], data_params['bin_size'])
        ipis_loc, hist_loc = clstr.get_histogram(location_df, fig_details['bin_step'])
        intervals_ms, survival = clstr.get_log_survival(hist_loc)

        fast_process = clstr.regress_around_fast_intervals(intervals_ms, survival, hist_loc[0])
        fast_process = clstr.calculate_exponential_coefficients(fast_process)

        slow_process = clstr.regress_around_slow_intervals(intervals_ms, survival)
        slow_process = clstr.calculate_exponential_coefficients(slow_process)

        fg_bci, misassigned_points_fg = clstr.get_bci_from_fagenyoung_method(fast_process, slow_process)
        print(f"Fagen&Young method has {round(misassigned_points_fg)} misassigned points")
        bci, misassigned_points = clstr.get_bci_from_slater_method(intervals_ms, survival, fast_process, slow_process)
        print(f"Slater method has {round(misassigned_points)} misassigned points")
        nlin_results, misassigned_points_optim = clstr.get_bci_from_sibly_method(intervals_ms, survival, fast_process, slow_process)
        print(f"Sibly method has {round(misassigned_points_optim)} misassigned points")
        print(f"Optim BCI has less misassignments than BCI? {misassigned_points_optim < misassigned_points}")
        if misassigned_points_optim < misassigned_points:
            diff = int(misassigned_points - misassigned_points_optim)
            sibly+=misassigned_points_optim
            print(f"{diff} more points assigned correctly by Sibly")
        else:
            diff = int(misassigned_points_optim - misassigned_points)
            slater+=misassigned_points
            print(f"{diff} more points assigned correctly by Slater")

        # bt_plt.plot_nlin_results_over_survival(intervals_ms, survival, fast_process, slow_process, nlin_results['solution'], nlin_results['bci'], bci, fig_details)

        data_params = dict()
        data_params['type_tag'] = freq_key
        data_params['site_tag'] = site_key
        data_params['cur_dc_tag'] = '1of6'
        data_params['bin_size'] = '30'
        data_params['detector_tag'] = 'bd2'
        data_params['use_thresholds'] = False
        data_params['assembly_type'] = 'kmeans'
        fig_details['site_name'] = SITE_NAMES[site_key] + ' ' + f"({data_params['cur_dc_tag']})"

        file_paths = get_file_paths(data_params)

        location_df = ss.prepare_summary_for_plotting_with_duty_cycle_and_bins(file_paths, data_params['cur_dc_tag'], data_params['bin_size'])
        ipis_loc, hist_loc = clstr.get_histogram(location_df, fig_details['bin_step'])
        intervals_ms, survival = clstr.get_log_survival(hist_loc)

        fast_process = clstr.regress_around_fast_intervals(intervals_ms, survival, hist_loc[0])
        fast_process = clstr.calculate_exponential_coefficients(fast_process)

        slow_process = clstr.regress_around_slow_intervals(intervals_ms, survival)
        slow_process = clstr.calculate_exponential_coefficients(slow_process)

        fg_bci, misassigned_points_fg = clstr.get_bci_from_fagenyoung_method(fast_process, slow_process)
        print(f"Fagen&Young method has {round(misassigned_points_fg)} misassigned points")
        bci, misassigned_points = clstr.get_bci_from_slater_method(intervals_ms, survival, fast_process, slow_process)
        print(f"Slater method has {round(misassigned_points)} misassigned points")
        nlin_results, misassigned_points_optim = clstr.get_bci_from_sibly_method(intervals_ms, survival, fast_process, slow_process)
        print(f"Sibly method has {round(misassigned_points_optim)} misassigned points")
        print(f"Optim BCI has less misassignments than BCI? {misassigned_points_optim < misassigned_points}")
        if misassigned_points_optim < misassigned_points:
            diff = int(misassigned_points - misassigned_points_optim)
            sibly+=misassigned_points_optim
            print(f"{diff} more points assigned correctly by Sibly")
        else:
            diff = int(misassigned_points_optim - misassigned_points)
            slater+=misassigned_points
            print(f"{diff} more points assigned correctly by Slater")

        # bt_plt.plot_nlin_results_over_survival(intervals_ms, survival, fast_process, slow_process, nlin_results['solution'], nlin_results['bci'], bci, fig_details)
# Out:
# Looking at Carp Pond
# Fagen&Young method has 2007839855 misassigned points
# Slater method has 3033010 misassigned points
# Sibly method has 2916334 misassigned points
# Optim BCI has less misassignments than BCI? True
# 116676 more points assigned correctly by Sibly
# Fagen&Young method has 1445640878 misassigned points
# Slater method has 1449602 misassigned points
# Sibly method has 1390431 misassigned points
# Optim BCI has less misassignments than BCI? True
# 59171 more points assigned correctly by Sibly
# Fagen&Young method has 1458229243 misassigned points
# Slater method has 1413260 misassigned points
# Sibly method has 1371979 misassigned points
# Optim BCI has less misassignments than BCI? True
# 41280 more points assigned correctly by Sibly
# Looking at Carp Pond
# Fagen&Young method has 1193583478 misassigned points
# Slater method has 1969127 misassigned points
# Sibly method has 2853760 misassigned points
# Optim BCI has less misassignments than BCI? False
# 884633 more points assigned correctly by Slater
# Fagen&Young method has 1526194780 misassigned points
# Slater method has 1291608 misassigned points
# /Users/adityakrishna/duty-cycle-investigation/daily_notebook/../src/bout/clustering.py:179: RuntimeWarning: overflow encountered in exp
#   return (np.log((f_intervals*f_lambda*np.exp(-1*f_lambda*t))  + (s_intervals*s_lambda*np.exp(-1*s_lambda*t))))
# /Users/adityakrishna/duty-cycle-investigation/daily_notebook/../src/bout/clustering.py:179: RuntimeWarning: overflow encountered in multiply
#   return (np.log((f_intervals*f_lambda*np.exp(-1*f_lambda*t))  + (s_intervals*s_lambda*np.exp(-1*s_lambda*t))))
# /Users/adityakrishna/duty-cycle-investigation/daily_notebook/../src/bout/clustering.py:179: RuntimeWarning: invalid value encountered in log
#   return (np.log((f_intervals*f_lambda*np.exp(-1*f_lambda*t))  + (s_intervals*s_lambda*np.exp(-1*s_lambda*t))))
# Sibly method has 1060118 misassigned points
# Optim BCI has less misassignments than BCI? True
# 231490 more points assigned correctly by Sibly
# Fagen&Young method has 1358936595 misassigned points
# Slater method has 1025930 misassigned points
# Sibly method has 1503857 misassigned points
# Optim BCI has less misassignments than BCI? False
# 477927 more points assigned correctly by Slater
# Looking at Foliage
# Fagen&Young method has 2375248923 misassigned points
# Slater method has 4052925 misassigned points
# Sibly method has 4047632 misassigned points
# Optim BCI has less misassignments than BCI? True
# 5293 more points assigned correctly by Sibly
# Fagen&Young method has 2678189020 misassigned points
# Slater method has 2789605 misassigned points
# Sibly method has 2968881 misassigned points
# Optim BCI has less misassignments than BCI? False
# 179276 more points assigned correctly by Slater
# Fagen&Young method has 2131607316 misassigned points
# Slater method has 2060909 misassigned points
# Sibly method has 2127575 misassigned points
# Optim BCI has less misassignments than BCI? False
# 66665 more points assigned correctly by Slater
# Looking at Foliage
# Fagen&Young method has 1549459205 misassigned points
# Slater method has 3106815 misassigned points
# Sibly method has 2593617 misassigned points
# Optim BCI has less misassignments than BCI? True
# 513197 more points assigned correctly by Sibly
# Fagen&Young method has 2096799406 misassigned points
# Slater method has 2129877 misassigned points
# Sibly method has 1834114 misassigned points
# Optim BCI has less misassignments than BCI? True
# 295762 more points assigned correctly by Sibly
# Fagen&Young method has 2176342320 misassigned points
# Slater method has 2392607 misassigned points
# Sibly method has 2171125 misassigned points
# Optim BCI has less misassignments than BCI? True
# 221481 more points assigned correctly by Sibly
# Looking at Telephone Field
# Fagen&Young method has 1681022428 misassigned points
# Slater method has 1577483 misassigned points
# Sibly method has 1578928 misassigned points
# Optim BCI has less misassignments than BCI? False
# 1445 more points assigned correctly by Slater
# Fagen&Young method has 483296403 misassigned points
# Slater method has 303543 misassigned points
# Sibly method has 314647 misassigned points
# Optim BCI has less misassignments than BCI? False
# 11104 more points assigned correctly by Slater
# Fagen&Young method has 818285907 misassigned points
# Slater method has 343134 misassigned points
# Sibly method has 423601 misassigned points
# Optim BCI has less misassignments than BCI? False
# 80467 more points assigned correctly by Slater
# Looking at Telephone Field
# Fagen&Young method has 827327557 misassigned points
# Slater method has 1811795 misassigned points
# Sibly method has 2523114 misassigned points
# Optim BCI has less misassignments than BCI? False
# 711319 more points assigned correctly by Slater
# Fagen&Young method has 1137644826 misassigned points
# Slater method has 960358 misassigned points
# Sibly method has 1365929 misassigned points
# Optim BCI has less misassignments than BCI? False
# 405571 more points assigned correctly by Slater
# Fagen&Young method has 1121868139 misassigned points
# Slater method has 894946 misassigned points
# Sibly method has 919474 misassigned points
# Optim BCI has less misassignments than BCI? False
# 24527 more points assigned correctly by Slater
# Looking at Central Pond
# Fagen&Young method has 1765550492 misassigned points
# Slater method has 2119061 misassigned points
# Sibly method has 2190000 misassigned points
# Optim BCI has less misassignments than BCI? False
# 70939 more points assigned correctly by Slater
# Fagen&Young method has 1361445726 misassigned points
# Slater method has 1248297 misassigned points
# Sibly method has 1313237 misassigned points
# Optim BCI has less misassignments than BCI? False
# 64940 more points assigned correctly by Slater
# Fagen&Young method has 1430176895 misassigned points
# Slater method has 1485166 misassigned points
# Sibly method has 1624879 misassigned points
# Optim BCI has less misassignments than BCI? False
# 139713 more points assigned correctly by Slater
# Looking at Central Pond
# Fagen&Young method has 1377158517 misassigned points
# Slater method has 2980422 misassigned points
# Sibly method has 2332391 misassigned points
# Optim BCI has less misassignments than BCI? True
# 648030 more points assigned correctly by Sibly
# Fagen&Young method has 1354451413 misassigned points
# Slater method has 1276631 misassigned points
# Sibly method has 1319757 misassigned points
# Optim BCI has less misassignments than BCI? False
# 43125 more points assigned correctly by Slater
# Fagen&Young method has 1405663657 misassigned points
# Slater method has 1270661 misassigned points
# Sibly method has 1035072 misassigned points
# Optim BCI has less misassignments than BCI? True
# 235588 more points assigned correctly by Sibly

# %%
slater
# Out:
# 19865983.24602947

# %%
sibly
# Out:
# 20752813.767731473
